# %% [markdown]
# # Problem Set 1 (93 points)

# %% [markdown]
# ## Important information
# We provide signatures of the functions that you have to implement. Make sure you follow the signatures defined, otherwise your coding solutions will not be graded.

# %% [markdown]
# # Problem 1 (Theoretical tasks)  (36 pts)
#
# _1._
# - (1 pts) what are the constants $C_1$ and $C_2$ such that $C_1 \|x\|_{2} \leq \|x\|_{\infty} \leq C_2 \| x\|_{2}$ for any vector $x$
# - (5 pts) Prove that $\| U A \|_F = \| A U \|_F = \| A \|_F$ for any unitary matrix $U$.
# - (5 pts) Prove that $\| U A \|_2 = \| A U \|_2 = \| A \|_2$ for any unitary matrix $U$.
#
# _2._
# - (5 pts) Using the results from the previous subproblem, prove that $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$. _Hint:_ SVD will help you.
# - (5 pts) Show that for any $m, n$ and $k \le \min(m, n)$ there exists $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, such that $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$. In other words, show that the previous inequality is not strict.
# - (5 pts) Prove that if $\mathrm{rank}(A) = 1$, then $\| A \|_F  = \| A \|_2$.
# - (5 pts) Prove that $\| A B \|_F \le \| A \|_2 \| B \|_F$.
#
# _3._
#
# - (2 pts) Let $U \in \mathbb{C}^{n \times k}, k < n$ be a matrix so that $U^*U = I_k$.
# Find a pseudoinverse of $UU^*$
# - (3 pts) Compute SVD of the matrix analytically, i.e. provide the analytical expression for every natural $n$
#
# $$
# A = \begin{bmatrix}
# 1\\
# \sqrt{3}\\
# \sqrt{5}\\
# \vdots\\
# \sqrt{2n-1}
# \end{bmatrix}
# \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix}
# $$

# %% [markdown]
# $\bullet 1.$
#
# $\circ$ Find $C_1, C_2: C_1 \|x\|_{2} \leq \|x\|_{\infty} \leq C_2 \| x\|_{2}$ for any vector $x$
#
# $\square \ \ \  C_1\le\frac{\|x\|_{\infty}}{\|x\|_2}, \ \ \ C_2\ge\frac{\|x\|_{\infty}}{\|x\|_2}$
#
# $\Vert x \Vert_2 =\sqrt{\sum_{i=1}^n x_i^2}\ge\sqrt{\max_i|x_i|^2}=\max_i|x_i|=\Vert x \Vert_{\infty}$
#
# Maximum of $\frac{\|x\|_{\infty}}{\|x\|_2}$ achieves, when we have only one element in vector x.
#
# For $x=e_{i} = [0,0,\dots, 1, \dots, 0]$: $\|x\|_2=1, \|x\|_{\infty}=1,  C_2\ge 1$  and $C_1\le 1$.
#
# $\Vert x \Vert_2 = \sqrt{\sum_{i=1}^n x_i^2}\le\sqrt{\sum_{i=1}^n (\max_i | x_i|) ^2}=\sqrt{n\cdot (\max_i | x_i|) ^2}=\sqrt{n}\cdot (\max_i | x_i|)=\sqrt{n}\cdot \Vert x \Vert_{\infty}$
#
# Minimum of $\frac{\|x\|_{\infty}}{\|x\|_2}$ achieves, when we have only all elements in vector x.
#
# For $x=[1,1,1,\dots,1]: C_1\le\frac{\|x\|_{\infty}}{\|x\|_2}\le\frac{1}{\sqrt{n}}, C_2\ge\frac{1}{\sqrt{n}}$.
#
#
# $\Rightarrow C_1=\frac{1}{\sqrt{n}}, \ \ C_2=1 \ \ \ \blacksquare$
#
#
#
#
# $\circ$ Prove: $\| U A \|_F = \| A U \|_F = \| A \|_F$
#
# $\square \ \ \ \| U A \|_F = \sqrt{tr(UA)^{*}(UA)} = \sqrt{tr(A^{*}U^{*}UA)}\overset{ U^{*}U=I}{=}\sqrt{tr(A^{*}A)}=\|A\|_F$
#
# $\| AU \|_F = \sqrt{tr(AU)^{*}(AU)} = \sqrt{tr(U^{*}A^{*}AU)}\overset{tr(ABC)=tr(CAB)}{=}\sqrt{tr(UU^{*}A^{*}A)}\overset{UU^{*}=I}{=}\sqrt{tr(A^{*}A)}=\|A\|_F = \| U A \|_F \ \ \ \blacksquare$
#
# $\circ$ Prove: $\| U A \|_2 = \| A U \|_2 = \| A \|_2$
#
# $\square \ \ \  \| A U \|_2 = \underset{x\neq 0}{sup}\frac{\|AUx\|_2}{\|x\|_2} \overset{\|Ux\|_2=\|x\|_2}{=} \underset{x\neq 0}{sup}\frac{\|AUx\|_2}{\|Ux\|_2} \overset{\|Ux\|_2=y}{=}\underset{y\neq 0}{sup}\frac{\|Ay\|_2}{\|y\|_2} = \|A\|_2 $
#
# $\|  UA \|_2 = \underset{x\neq 0}{sup}\frac{\|UAx\|_2}{\|x\|_2} \overset{\|UAx\|_2=\|Ax\|_2}{=}\|A\|_2 = \|AU\|_2 \ \ \ \blacksquare$
#
#
#
# $\bullet 2.$
#
# $\circ$ Prove $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$
#
# $\square $ According to SVD theorem we could get singular value decomposition for matrix $A\in C^{mxn}$ such as $A =V\Sigma U^{*}$, where $V\in C^{mxm}$ and $U\in C^{nxn}$ - unitary matrices, r=rank(A) , $\Sigma = diag(\sigma_{1}, \dots, \sigma_{r})$ is diag matrix with dimension mxn and $\sigma_{1}\ge\dots\ge\sigma_{r}>0$.
#
# $\| A \|_F =\|V\Sigma U^{*}\|_F=\|\Sigma\|_F=\sqrt{\sigma_{1}^{2}+\sigma_{2}^{2}+\dots +\sigma_{r}^{2}}\le \sigma_{1}\sqrt{r}=|\|A\|_2=\sigma_{1}|=\sqrt{rank(A)}\|A\|_2 \ \ \ \blacksquare$
#
# $\circ$ Prove $\| A \|_F =\sqrt{\mathrm{rank}(A)} \| A \|_2$
#
# $\square$ Suppose matrix A has rank(A)=r and  $\sigma_{1}=\sigma_{2}=\dots=\sigma_{r}$. Then $ \| A \|_F = \sqrt{r}\sigma_{1}$ and $\| A \|_2=\sigma_{1} \ \ \ \blacksquare$
#
# $\circ$  Prove that if $\mathrm{rank}(A) = 1$, then $\| A \|_F  = \| A \|_2$.
#
# $\square \ \ \ \| A \|_F = \|\Sigma\|_F=\sigma_{1}=\|A\|_2 \ \ \ \blacksquare$
#
# $\circ$ Prove that $\| A B \|_F \le \| A \|_2 \| B \|_F$.
#
# $\square\ \ \ \| A B \|_F \overset{SVD: A=U\Sigma V^{*}}{\le} \|U\Sigma V^{*}B\|_F\overset{V^{*}B=C}{=}\|U\Sigma C\|_F=\|\Sigma C\|_F=\begin{Vmatrix}
# \begin{pmatrix}
# \sigma_{1}c_{1}  \\
# \sigma_{2}c_{2} \\
# \dots \\
# \sigma_{r}c_{r}
# \end{pmatrix}
# \end{Vmatrix} = (\sum_{i=1}^{n}\sigma_{i}^{2}\|c_{i}\|_2^{2})^{\frac{1}{2}}\le \sigma_{1}(\sum_{i=1}^{n}\|c_{i}\|_2^{2})^{\frac{1}{2}}=\sigma_{1}\|C\|_F=\|A\|_2\|V^{*}B\|_F= \|A\|_2\|B\|_F \ \ \ \blacksquare$
#
# $\bullet 3.$
#
# $\circ$ Find pseudoinverse for $UU^{*}$
#
# $\square$
#
# $U^{*}U=I_{k}$
#
# It's obvious that $(UU^{*})^{k}=UU^{*}$ for $k\ge 1$.
#
#
# Prove that pseudoinverse matrix for $UU^{*}$ is itself.
#
# $A=UU^{*}, A^{+}=UU^{*}$
#
# Use svd for it:
#
# $A=D\Sigma V^{*}$
#
# $A^{*} = A = V\Sigma^{*} D^{*}$
#
# From lecture pseudoinverse matrix of A is $A^{+}=V\Sigma^{+}D^{*}$.
#
# If we prove that $\Sigma^{*} = \Sigma^{+}$, then
#
# $A^{+}=A^{*}=A$.
#
# Consider singular values of $UU^{*}$.
#
# $UU^{*}\vec{d}=\sigma \vec{v} \ \ (1)$
#
# $UU^{*}\vec{v}=\sigma \vec{d} \ \ (2)$
#
# Multiply from left on $U^{*}$.
#
# $U^{*}\vec{d}=\sigma U^{*}\vec{v} \ \ (1)$
#
# $U^{*}\vec{v}=\sigma U^{*}\vec{d} \ \ (2)$
#
# Multiply secon equation on $\sigma$ and equal to first one:
#
# $\sigma^{2}U^{*}\vec{d}=U^{*}\vec{d}\Rightarrow \sigma^{2}=1\Rightarrow \Sigma^{+}=\Sigma^{*}$
#
# Then the pseudoinverse matrix is equal to $UU^{*} $
#
#
#
#
# Also we could check the definition for pseudoinverse matrix checking this equitions:
#
# $AA^{+}A=A \ \ (1)$
#
# $A^{+}AA^{+}=A^{+} \ \ (2) $
#
# $(AA^{+})^{*}=AA^{+} \ \ (3)$
#
#  $(A^{+}A)^{*}=A^{+}A \ \ (4)  \ \ \ \blacksquare$
#
#  $\circ$ Compute SVD of the matrix analytically, i.e. provide the analytical expression for every natural n
#
# $$ A = \begin{bmatrix}
# 1\\
# \sqrt{3}\\
# \sqrt{5}\\
# \vdots\\
# \sqrt{2n-1}
# \end{bmatrix}
# \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix}
# $$
#
# $\square$
#
# $U=\begin{bmatrix}
# 1\\
# \sqrt{3}\\
# \sqrt{5}\\
# \vdots\\
# \sqrt{2n-1}
# \end{bmatrix}$
#
# $V^{*}=\begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix} $
#
# Normalize vectors to get unitary matrix:
#
# $\overline{U}=\frac{1}{\sqrt{1+9+\dots + (2n-1)^{2}}}U=\frac{1}{\sqrt{n^{2}}}U=\frac{1}{n}U=\begin{bmatrix}
# \frac{1}{n}\\
# \frac{\sqrt{3}}{n}\\
# \frac{\sqrt{5}}{n}\\
# \vdots\\
# \frac{\sqrt{2n-1}}{n}
# \end{bmatrix}$
#
# $\overline{V^{*}}=\frac{1}{\sqrt{n}}V=\begin{bmatrix}
# -\frac{1}{\sqrt{n}} & \frac{1}{\sqrt{n}} & -\frac{1}{\sqrt{n}} & \ldots & (-\frac{1}{\sqrt{n}})^{n}
# \end{bmatrix}$
#
# $A=UV^{*}=n^{\frac{3}{2}}\overline{U}\overline{V^{*}} = \overline{U}\Sigma\overline{V^{*}},$
#
# where $\Sigma=[n^{\frac{3}{2}}]$
#
#
#
# $\blacksquare$

# %% [markdown]
# # Problem 2 (Matrix calculus) (12 pts)
#
# _1._ (10 pts) Consider the following function
#
# $$ F(U, V) = \frac{1}{2}\|X - UV\|_F^2, $$
#
# where $X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$ and $V \in \mathbb{R}^{k \times n}$ and $k < n$.
#
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $U$
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $V$
# - (6 pts) Estimate computational complexity of computing these gradients (in big-O notation). Also, compare timing of analytical computations versus timing the automatic differentiation with JAX. Study some range of dimensions to extract asymptotic complexity and make a conclusion, what approach is faster. Plot the dependence of running time on the dimension (row and column separately) to proof your conclusion
#
# _2._ (2 pts) Derive analytical expression for the gradient of the function $f$:
#
# $$ R(x) = \frac{(Ax, x)}{(x, x)}, $$
#
# where $A$ is a symmetric real matrix. Why the gradient of this function is important in NLA you will know in the lectures later.

# %% [markdown]
# $\bullet 1. $
#
# $F(U, V)=\frac{1}{2}(<X-UV,X-UV>)$
#
# $\circ \ \ \ \frac{\partial F}{\partial U}=-(X-UV)V^{T}$
#
# $\circ \ \ \ \frac{\partial F}{\partial V}=-U^{T}(X-UV)$
#
# $\circ$ The complexity of matrix multiplication without block improvement is $O(n^{2}k)$. In our case because we have no knowledge about structure of matrices the complexity of computing gradients  is $3O(n^{2}k)$, as we compute matrix multiplication 3 times. Graphics are in next cell.
#
# Answer $O(n^{2}k).$
#
# $\bullet 2. $
#
# $x\in \mathbb{R}^{d \times 1}$
#
# $A\in \mathbb{R}^{d \times d}$
#
#
#
# $R^{'}(x)=\frac{x^{T}(A+A^{T})x^{T}x - x^{T}Ax(2x^{T})}{\|x\|_2^{4}}=\frac{2x^{T}A\|x\|_2^{2}-x^{T}Ax(2x^{T})}{\|x\|_2^{4}}=
# \frac{2x^{T}A}{\|x\|_2^{2}}-\frac{2x^{T}I_{d}(x^{T}Ax)}{\|x\|_2^{4}}=\frac{2x^{T}}{\|x\|_{2}^{2}}(A-\frac{x^{T}Ax}{\|x\|_2^{2}}I_{d})$

# %%
# Your solution is here
import time
import jax
import jax.numpy as jnp
from jax import grad, jit, vmap
from jax import random

def create_matrices(k, n, key):
  X = jax.random.uniform(key, (n,n))
  V = jax.random.uniform(key, (k,n))
  U = jax.random.uniform(key, (n,k))
  return X, U, V

@jax.jit
def func(X, U, V):
  f = X - U@V
  return 0.5 * jnp.linalg.norm(f,ord = 'fro')**2

def analytic_grads_U(X, U, V):
  return (U@V-X)@(V.T)

def analytic_grads_V(X, U, V):
  return (U.T)@(U@V-X)

# %%
n = [i*100 for i in range(22)]
k = [100]*22

grad_U_time = []
grad_V_time = []
analyt_U_time = []
analyt_V_time = []

avg_num = 5

for i in zip(k, n):
# averaging time results generating avg_num matrices
# compute grads for U with jax
  for j in tqdm(range(avg_num)):
    time_for_avg = []
    X, U, V = create_matrices(i[0], i[1], jax.random.PRNGKey(j+100))
    start_time = time.time()
    U_grad = grad(func, (1))(X, U, V)
    time_for_avg.append(time.time()-start_time)
  grad_U_time.append(jnp.sqrt(jnp.array(time_for_avg).mean()))

# compute grads for V with jax
  for j in tqdm(range(avg_num)):
    time_for_avg = []
    X, U, V = create_matrices(i[0], i[1], jax.random.PRNGKey(j+100))  
    start_time = time.time()
    V_grad = grad(func, (2))(X, U, V)
    time_for_avg.append(time.time()-start_time)
  grad_V_time.append(jnp.sqrt(jnp.array(time_for_avg).mean()))

# compute grads for U with analytic formula
  for j in tqdm(range(avg_num)):
    time_for_avg = []
    X, U, V = create_matrices(i[0], i[1], jax.random.PRNGKey(j+100))  
    start_time = time.time()
    U_grada = analytic_grads_U(X, U, V)
    time_for_avg.append(time.time()-start_time)
  analyt_U_time.append(jnp.sqrt(jnp.array(time_for_avg).mean()))

# compute grads for V with analytic formula
  for j in tqdm(range(avg_num)):
    time_for_avg = []
    X, U, V = create_matrices(i[0], i[1], jax.random.PRNGKey(j+100))
    start_time = time.time()
    V_grada = analytic_grads_V(X, U, V)
    time_for_avg.append(time.time()-start_time)
  analyt_V_time.append(jnp.sqrt(jnp.array(time_for_avg).mean()))
# Out:
# ...
# 100%|██████████| 5/5 [00:00<00:00, 10.54it/s]

# %%
from matplotlib import pyplot as plt
# plot with various axes scales

plt.figure(figsize=(20,10))
# linear
plt.subplot(221)
plt.title("jax and analytic gradients for U depend on n")
plt.plot(n, analyt_U_time, 'r', label='analytic')
plt.plot(n, grad_U_time, 'b', label='jax')
plt.xlabel('n')
plt.ylabel('$\sqrt{time}$')
plt.legend()
plt.subplot(222)
plt.title("jax and analytic gradients for V depend on n")
plt.plot(n, analyt_V_time, 'r', label='analytic')
plt.plot(n, grad_V_time, 'b', label='jax')
plt.xlabel('n')
plt.ylabel('$\sqrt{time}$')
plt.legend()
plt.show()

# %% [markdown]
# As we can see the dependence for $\sqrt{time} \ $is linear, so $time=Cn^{2} $looks correct.

# %%
from tqdm import tqdm

k = [i for i in range(10, 1000, 100)]
n = [1000]*len(k)
grad_U_time = []
grad_V_time = []
analyt_U_time = []
analyt_V_time = []

avg_num = 5

for i in zip(k, n):
# averaging time results generating avg_num matrices
# compute grads for U with jax
  for j in tqdm(range(avg_num)):
    time_for_avg = []
    X, U, V = create_matrices(i[0], i[1], jax.random.PRNGKey(j+100))
    start_time = time.time()
    U_grad = grad(func, (1))(X, U, V)
    time_for_avg.append(time.time()-start_time)
  grad_U_time.append(jnp.array(time_for_avg).mean())

# compute grads for V with jax
  for j in tqdm(range(avg_num)):
    time_for_avg = []
    X, U, V = create_matrices(i[0], i[1], jax.random.PRNGKey(j+100))  
    start_time = time.time()
    V_grad = grad(func, (2))(X, U, V)
    time_for_avg.append(time.time()-start_time)
  grad_V_time.append(jnp.array(time_for_avg).mean())

# compute grads for U with analytic formula
  for j in tqdm(range(avg_num)):
    time_for_avg = []
    X, U, V = create_matrices(i[0], i[1], jax.random.PRNGKey(j+100))  
    start_time = time.time()
    U_grada = analytic_grads_U(X, U, V)
    time_for_avg.append(time.time()-start_time)
  analyt_U_time.append(jnp.array(time_for_avg).mean())

# compute grads for V with analytic formula
  for j in tqdm(range(avg_num)):
    time_for_avg = []
    X, U, V = create_matrices(i[0], i[1], jax.random.PRNGKey(j+100))
    start_time = time.time()
    V_grada = analytic_grads_V(X, U, V)
    time_for_avg.append(time.time()-start_time)
  analyt_V_time.append(jnp.array(time_for_avg).mean())
# Out:
# ...
# 100%|██████████| 5/5 [00:00<00:00, 10.75it/s]

# %%
plt.figure(figsize=(20,10))
# linear
plt.subplot(221)
plt.title("jax and analytic gradients for U depend on k")
plt.plot(k, analyt_U_time, 'r', label='analytic')
plt.plot(k, grad_U_time, 'b', label='jax')
plt.xlabel('k')
plt.ylabel('time')
plt.legend()
plt.subplot(222)
plt.title("jax and analytic gradients for V depend on k")
plt.plot(k, analyt_V_time, 'r', label='analytic')
plt.plot(k, grad_V_time, 'b', label='jax')
plt.xlabel('k')
plt.ylabel('time')
plt.legend()
plt.show()

# %% [markdown]
# In this case with changing k computation of analytic gradients increase slowly while jax respond to our assumption $time=Ck$.

# %% [markdown]
# # Problem 3. Compression of the fully-connected layers in neural network with simple architecture (30 pts)
#
# In this problem we consider the neural network that performs classification of the dataset of images.
# Any neural network can be considered as composition of simple linear and non-linear functions.
# For example, a neural network with 3 layers can be represented as
#
# $$f_3(f_2(f_1(x, w_1), w_2), w_3),$$
#
# where $x$ is input data (in our case it will be images) and $w_i, \; i =1,\dots,3$ are parameters that are going to be trained.
#
# We will study the compression potential of neural network with simple architecture: alternating some numbers of linear and non-linear functions.
#
# The main task in this problem is to study how the compression of fully-connected layers affects the test accuracy.
# Any fully-connected layer is represented as linear function $AX + B$, where $X$ is input matrix and $A, B$ are trainable matrices. Matrices $A$ in every layer are going to be compressed.
# The main result that you should get is the plot of dependence of test accuracy on the total number of parameters in the neural network.

# %% [markdown]
# #### Zero step: install PyTorch
#
# - Follow the steps in [official instructions](https://pytorch.org/get-started/locally/)

# %% [markdown]
# #### First step: download CIFAR10 dataset

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=True, download=True, transform=transform), 
                                        batch_size=batch_size, shuffle=True)

test_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=False, transform=transform), 
                                          batch_size=batch_size, shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ...
# Extracting ./cifar-10-python.tar.gz to ./

# %% [markdown]
# #### Check what images are we going to classify

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(20, 10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
#  deer truck horse  deer truck  frog  bird  deer

# %% [markdown]
# ### Second step: neural network architecture
#
# For simplicity and demonstration purposes of the neural network compression idea consider the architecture consisting of the only fully-connected layers and non-linear ReLU functions between them.
# To demonstrate compression effect, consider the dimension of the inner layers equals to 1000.
#
# Below you see implementation of such neural network in PyTorch.
# More details about neural networks you will study in the *Deep learning* course in one of the upcoming term

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3 * 32 * 32, 1000)
        self.fc2 = nn.Linear(1000, 1000)
        self.fc3 = nn.Linear(1000, 1000)
        self.fc4 = nn.Linear(1000, 1000)
        self.fc5 = nn.Linear(1000, 1000)
        self.fc6 = nn.Linear(1000, 10)
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.fc2(x)
        x = self.ReLU(x)
        x = self.fc3(x)
        x = self.ReLU(x)
        x = self.fc4(x)
        x = self.ReLU(x)
        x = self.fc5(x)
        x = self.ReLU(x)
        x = self.fc6(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# #### Implement functions for training and testing after every sweep over all dataset entries

# %%
def train(model, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
#             data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    accuracy = 100. * correct / len(test_loader.dataset)
    return accuracy

# %% [markdown]
# ### Set parameters for training and print intermediate loss values

# %%
log_interval = 50
epochs = 5

# %% [markdown]
# ### Third step: run training with the [Adam](https://arxiv.org/pdf/1412.6980.pdf%20%22%20entire%20document) optimization method
#
# If your laptop is not very fast, you will wait some time till training is finished.

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(model,  train_loader, optimizer, epoch)
    test(model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.299321
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.910089
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.805799
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.869200
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.747238
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.787288
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.673234
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.688684
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.694169
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.685165
#
# Test set: Average loss: 1.5635, Accuracy: 4477/10000 (45%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.522632
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.761360
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.575529
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.531850
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.438291
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.538751
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.581860
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.553079
# ...

# %% [markdown]
# Now we have somehow trained neural network and we are ready to perform compression of the weigths in the fully-connected layers.

# %% [markdown]
# - (3 pts) Compute SVD of the matrix $1000 \times 1000$, which corresponds to a weight matrix $A$ in any layer of the trained neural network of the appropriate dimension. To find more information about accessing this matrix please refer to [PyTorch manual](https://pytorch.org/docs/stable/index.html).
# Plot decaying of the singular values like it was shown in the lecture. What conclusion can you make?
# - (17 pts) Create a new model, which is an analogue to the class ```Net```, but with some significant distinctions.
# It takes as input parameters the instance of the class ```Net``` and compression rank $r > 0$.
# After that, this model has to compress all matrices $A$ in fully-connected layers with SVD using first $r$ singular vectors and singular values.
# Pay attention to efficient storing of compress representation of the layers.
# Also ```forward``` method of your new model has to be implemented in a way to use compressed representation of the fully-connected layers in the most efficient way. In all other aspects it has to reproduce ```forward``` method in the original non-compressed model (number of layers, activations, loss function etc).
# - (5 pts) Plot dependence of test accuracy on the number of parameters in the compressed model. This number of parameters obviously depends on the compression rank $r$.
# Also plot dependence of time to compute inference on the compression rank $r$.
# Explain obtained results.
# To measure time, use [%timeit](https://docs.python.org/3.6/library/timeit.html) with necessary parameters (examples of using this command see in lectures)
#
# - (5 pts) After such transformations, your model depends on the factors obtained from SVD. Therefore, these factors are also can be trained with the same gradient method during some number of epochs. This procedure is called fine-tuning. We ask you make this fine-tuning of your compressed model during from 1 to 5 epoch and compare the result test accuracy with the test accuracy that you get after compression. Explain the observed results

# %%
# Your solution is here
from matplotlib import pyplot as plt
weight_matrix = model.fc2.weight.detach()
u, s, v = torch.svd(weight_matrix)
# check that everything works normal
print('svd accuracy is',torch.dist(weight_matrix, torch.mm(torch.mm(u, torch.diag(s)), v.t())))
# plot singular values
plt.title('Decaying of singular values')
plt.semilogy(s/s[0])
plt.xlabel('index of singular value')
plt.ylabel('$\sigma_i / \sigma_0$')
plt.grid(True)
plt.show();
# Out:
# svd accuracy is tensor(6.1749e-05)

# %% [markdown]
# According to this graph we could see that only N singular values are meaningful. That means that we could reduce the number of trained parameters in linear layers. So let's use compression.

# %%
from torch.nn.parameter import Parameter
import torch.nn.functional as F

class CLinear(nn.Module):
  def __init__(self, layer, r):
    super(CLinear, self).__init__()
    u, s, v = torch.svd_lowrank(layer.weight.data, q=r)
    self.v = Parameter(v)
    self.clayer = Parameter(u@torch.diag(s))
    self.bias = Parameter(layer.bias)

  def forward(self, input):
    mm = self.clayer@self.v.T
    return F.linear(input, mm, self.bias)

# %%
class CNet(nn.Module):
    def __init__(self, model, r):
        super(CNet, self).__init__()
        self.fc1 = model.fc1
        self.fc2 = CLinear(model.fc2, r)
        self.fc3 = CLinear(model.fc3, r)
        self.fc4 = CLinear(model.fc4, r)
        self.fc5 = CLinear(model.fc5, r)
        self.fc6 = model.fc6
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.fc2(x) 
        x = self.ReLU(x)
        x = self.fc3(x)
        x = self.ReLU(x)
        x = self.fc4(x)
        x = self.ReLU(x)
        x = self.fc5(x)
        x = self.ReLU(x)
        x = self.fc6(x)
        return F.log_softmax(x, dim=1)

# %%
def count_params(model):
    return sum(p.numel() for p in model.parameters())

# %%
import time
from copy import deepcopy
from tqdm import tqdm

inference_time = []
num_params = []
inference_accuracy = []
r_list = []

for r in tqdm(range(100, 1000, 400)):
  model_copy = deepcopy(model)
  cmodel = CNet(model_copy, r)
  time = %timeit -o -n 1 test(cmodel, test_loader)
  inference_time.append(np.array(time.all_runs).mean())
  inference_accuracy.append(test(cmodel, test_loader))
  num_params.append(count_params(cmodel))
  r_list.append(r)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Test set: Average loss: 1.3638, Accuracy: 5287/10000 (53%)
#
#
# Test set: Average loss: 1.3638, Accuracy: 5287/10000 (53%)
#
#
# Test set: Average loss: 1.3638, Accuracy: 5287/10000 (53%)
#
# 1 loop, best of 3: 6.48 s per loop
#  33%|███▎      | 1/3 [00:26<00:53, 26.62s/it]
# Test set: Average loss: 1.3638, Accuracy: 5287/10000 (53%)
#
#
# Test set: Average loss: 1.3602, Accuracy: 5283/10000 (53%)
#
#
# Test set: Average loss: 1.3602, Accuracy: 5283/10000 (53%)
#
#
# Test set: Average loss: 1.3602, Accuracy: 5283/10000 (53%)
#
# 1 loop, best of 3: 11.3 s per loop
#  67%|██████▋   | 2/3 [01:13<00:32, 32.61s/it]
# Test set: Average loss: 1.3602, Accuracy: 5283/10000 (53%)
#
#
# Test set: Average loss: 1.3618, Accuracy: 5295/10000 (53%)
#
#
# Test set: Average loss: 1.3618, Accuracy: 5295/10000 (53%)
#
#
# Test set: Average loss: 1.3618, Accuracy: 5295/10000 (53%)
#
# 1 loop, best of 3: 16.5 s per loop
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.title('Dependence of test accuracy on the number of parameters')
plt.plot(num_params, inference_accuracy)
plt.ylabel('inference_accuracy')
plt.xlabel('num_params')
plt.show()
plt.title('Dependence of inference time on the compression rank r')
plt.plot( r_list, inference_time)
plt.ylabel('inference time')
plt.xlabel('compression rank r')
plt.show()

# %% [markdown]
# So accuracy and inference time increases with the number of parameters and compression rank.

# %%
# Start finetuning
finetune_time = []
finetune_params = []
finetune_accuracy = []
all_acc = []
all_time = []


epochs = 5

for r in tqdm(range(100, 1000, 400)):
  model_copy = deepcopy(model)
  cmodel = CNet(model_copy, r)
  coptimizer = optim.Adam(cmodel.parameters(), lr=1e-3)
  for epoch in range(1, epochs + 1):
    train(cmodel,  train_loader, coptimizer, epoch)
    time = %timeit -o -n 1 test(cmodel, test_loader)
    finetune_time.append(time)
    finetune_accuracy.append(test(cmodel, test_loader))
    finetune_params.append(count_params(cmodel))
  all_acc.append(finetune_accuracy)
  all_time.append(finetune_time)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Train Epoch: 1 [0/50000 (0%)]	Loss: 1.129868
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.108861
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.086731
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.108165
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.205707
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.070011
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.206779
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.166451
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.081135
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.104169
#
# Test set: Average loss: 1.3927, Accuracy: 5216/10000 (52%)
#
#
# Test set: Average loss: 1.3927, Accuracy: 5216/10000 (52%)
#
#
# Test set: Average loss: 1.3927, Accuracy: 5216/10000 (52%)
#
# 1 loop, best of 3: 6.47 s per loop
#
# Test set: Average loss: 1.3927, Accuracy: 5216/10000 (52%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.031941
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 0.929289
# ...

# %%
# take accuracy for each r at 5-th epoch
finetune_acc = [i[-1] for i in all_acc]
print(finetune_acc)
# Out:
# [52.59, 52.59, 52.59]

# %%
r_list
# Out:
# [100, 500, 900]

# %%
plt.title('Dependence of test accuracy before and after finetuning for r = [100, 500, 900]')
plt.plot( r_list,inference_accuracy, label = 'without finetune')
plt.plot(r_list,finetune_acc, label = 'with finetune')
plt.ylabel('accuracy')
plt.xlabel('r')
plt.legend()
plt.show()

# %% [markdown]
# After finetuning usually we could improve accuracy by training compressed model for more epoch, but in this case we get no improvement.
#
# I think we need more epoch for training to improve obtained result. But no matter of it we wouldn't increase accuracy a lot.
#
# To improve the performence of our classification problem we should use more complex structure of layers and increase the number of trainable parameters.

# %% [markdown]
# ## Problem 4. «Reducio!» (15 pts)

# %% [markdown]
# Hermione Granger is well versed in all magical disciplines. In particular, she is a great expert in Numerical Linear Algebra and JAX.
#
# She has invited Harry Potter to play the game.
#
# Hermione chooses a number $r \in [1, 95]$ and two matrices $W_1 \in \mathbb{R}^{r \times 100}$ and $W_2 \in \mathbb{R}^{100 \times r}$.
# Harry can tell her any 100-dimensional vector $x$, and Hermione gives Harry the result of
#
# $$
# \sin(W_2 \cos(W_1 x)),$$
#
# where trigonometric functions are applied element-wise.
# This result is also a 100-dimensional vector.
#
# Not to lose, Harry should guess what number $r$ Hermione has chosen.
# Harry knows the python language, but he is an absolute layman in algebra. Please, help him to get at least 95% correct answers!
#
# <i> Hint 1: SVD might help you, but use it wisely! </i>
#
# <i> Hint 2: Suppose that a special magic allows you to compute gradients through automatic differentiation in JAX. You can also estimate gradients via finite differences, if you want it.</i>
#
# <i> Hint 3: You can estimate the matrix rank using simple heuristics.
#
# You should write code into the `harry_answers` function. Good luck!

# %%
import jax.numpy as jnp
import jax
from jax import grad
import numpy as np
import random

class Game:
    def __init__(self, key):
        # key is a jax.random.PRNGKey
        self.key = key
        return
    def hermione_chooses_r_and_W(self):
        self.r = random.randint(1, 95)
        self.key, subkey = jax.random.split(self.key)
        self.W1 = jax.random.uniform(subkey, (self.r, 100), maxval=100., minval=0., dtype=jnp.float32)
        self.key, subkey = jax.random.split(self.key)
        self.W2 = jax.random.uniform(subkey, (100, self.r), maxval=100., minval=0., dtype=jnp.float32)
    def hermione_computes_function(self, x):
        return jnp.sin(self.W2 @ jnp.cos(self.W1 @ x))
    def func_wrapper(self, x):
        return self.hermione_computes_function(x).mean()
    def harry_answers(self):
        # create array from random uniform distribution
        subkey = jax.random.PRNGKey(713)
        X = jax.random.uniform(subkey, (100, 100), maxval=100., minval=0., dtype=jnp.float32)
        grad_f_list = []
        for i in range(100):
          x = X[:,i]
          grad_f_list.append(grad(self.func_wrapper)(x))
        u, s, vh = jnp.linalg.svd(np.array(grad_f_list).T, full_matrices=True)
        # singular values > 0.5 True, else False
        a=s>0.5       
        # you shouldn't use self.r, self.W1, or self.W2
        # you can call `hermione_computes_function` multiple times
        r = a.sum() # number of singular values>0.5
        return r
    
    def play(self, n_rounds, verbose=True):
        # n_rounds: a number of rounds of the game
        # verbose: print or not the result of each round
        n_right_answers = 0
        for _ in tqdm(range(n_rounds)):
            self.hermione_chooses_r_and_W()
            r = self.harry_answers()
            if abs(r - self.r) == 0:
                if verbose:
                    print("Good job! The true answer is {}, Harry's answer is {}!".format(self.r, r))
                n_right_answers += 1
            else:
                if verbose:
                    print("Harry's answers is {}, but the true answer is {} :(".format(r, self.r))
        if float(n_right_answers) / n_rounds > 0.95:
            print('Well done: {}/{} right answers!'.format(n_right_answers, n_rounds))
        else:
            print('Only {}/{} right answers :( Work a little more and you will succeed!'.format(
                n_right_answers, n_rounds))

# %%
key = jax.random.PRNGKey(713)
game = Game(key)
game.play(n_rounds=10, verbose=False)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#  10%|█         | 1/10 [00:01<00:12,  1.36s/it]
#
#
#  20%|██        | 2/10 [00:02<00:11,  1.38s/it]
#
#
#  30%|███       | 3/10 [00:04<00:09,  1.40s/it]
#
#
#  40%|████      | 4/10 [00:05<00:08,  1.41s/it]
#
#
#  50%|█████     | 5/10 [00:07<00:07,  1.48s/it]
#
#
#  60%|██████    | 6/10 [00:08<00:05,  1.34s/it]
#
#
#  70%|███████   | 7/10 [00:10<00:04,  1.48s/it]
#
#
#  80%|████████  | 8/10 [00:11<00:03,  1.50s/it]
#
#
#  90%|█████████ | 9/10 [00:13<00:01,  1.56s/it]
#
#
# 100%|██████████| 10/10 [00:14<00:00,  1.50s/it]
# Well done: 10/10 right answers!

# %% [markdown]
# # Problem 5 (Bonus)
#
# 1. The norm is called absolute if $\|x\|=\| \lvert x \lvert \|$ holds for any vector $x$, where $x=(x_1,\dots,x_n)^T$ and $\lvert x \lvert = (\lvert x_1 \lvert,\dots, \lvert x_n \lvert)^T$. Give an example of a norm which is not absolute.
#
# 2. Write a function ```ranks_HOSVD(A, eps)```
# that calculates Tucker ranks of a d-dimensional tensor $A$ using High-Order SVD (HOSVD) algorithm, where ```eps``` is the relative accuracy in the Frobenius norm between the approximated and the initial tensors. Details can be found [here](http://ca.sandia.gov/~tgkolda/pubs/pubfiles/TensorReview.pdf) on Figure 4.3.
# ```python
# def ranks_HOSVD(A, eps):
#       return r #r should be a tuple of ranks r = (r1, r2, ..., rd)
# ```
